# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Data preprocess

# %% [markdown]
# Loading the Iris dataset from scikit-learn. Here, the third column represents the petal length, and the fourth column the petal width of the flower samples. The classes are already converted to integer labels where 0=Iris-Setosa, 1=Iris-Versicolor, 2=Iris-Virginica.

# %%
from sklearn import datasets
import numpy as np

iris = datasets.load_iris()
X = iris.data[:, [2, 3]]
y = iris.target

print('Class labels:', np.unique(y))
# Out:
# Class labels: [0 1 2]

# %%
X
# Out:
# array([[1.4, 0.2],
#        [1.4, 0.2],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.7, 0.4],
#        [1.4, 0.3],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.5, 0.1],
#        [1.5, 0.2],
#        [1.6, 0.2],
#        [1.4, 0.1],
#        [1.1, 0.1],
#        [1.2, 0.2],
#        [1.5, 0.4],
#        [1.3, 0.4],
#        [1.4, 0.3],
#        [1.7, 0.3],
#        [1.5, 0.3],
#        [1.7, 0.2],
#        [1.5, 0.4],
#        [1. , 0.2],
#        [1.7, 0.5],
#        [1.9, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.4],
#        [1.5, 0.2],
#        [1.4, 0.2],
#        [1.6, 0.2],
#        [1.6, 0.2],
#        [1.5, 0.4],
#        [1.5, 0.1],
#        [1.4, 0.2],
#        [1.5, 0.2],
#        [1.2, 0.2],
#        [1.3, 0.2],
#        [1.4, 0.1],
#        [1.3, 0.2],
#        [1.5, 0.2],
#        [1.3, 0.3],
#        [1.3, 0.3],
#        [1.3, 0.2],
#        [1.6, 0.6],
#        [1.9, 0.4],
#        [1.4, 0.3],
#        [1.6, 0.2],
# ...

# %% [markdown]
# Splitting data into 70% training and 30% test data:

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=1, stratify=y)#stratify表示根据标签的比例分层抽样

# %%
print('Labels counts in y:', np.bincount(y))#查看不同数值的比例
print('Labels counts in y_train:', np.bincount(y_train))
print('Labels counts in y_test:', np.bincount(y_test))
# Out:
# Labels counts in y: [50 50 50]
# Labels counts in y_train: [35 35 35]
# Labels counts in y_test: [15 15 15]

# %% [markdown]
# Standardizing the features:

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
sc.fit(X_train)
X_train_std = sc.transform(X_train)
X_test_std = sc.transform(X_test)

# %% [markdown]
# # Visualization

# %%
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt

def plot_decision_regions(X, y, classifier, test_idx=None, resolution=0.02):

    # setup marker generator and color map
    markers = ('s', 'x', 'o', '^', 'v')
    colors = ('red', 'blue', 'lightgreen', 'gray', 'cyan')
    cmap = ListedColormap(colors[:len(np.unique(y))])

    # plot the decision surface
    x1_min, x1_max = X[:, 0].min() - 1, X[:, 0].max() + 1
    x2_min, x2_max = X[:, 1].min() - 1, X[:, 1].max() + 1
    xx1, xx2 = np.meshgrid(np.arange(x1_min, x1_max, resolution),
                           np.arange(x2_min, x2_max, resolution))#生成网格坐标矩阵
    Z = classifier.predict(np.array([xx1.ravel(), xx2.ravel()]).T)
    Z = Z.reshape(xx1.shape)
    plt.contourf(xx1, xx2, Z, alpha=0.3, cmap=cmap)#填充等高线轮廓，即划分区域
    plt.xlim(xx1.min(), xx1.max())
    plt.ylim(xx2.min(), xx2.max())

    for idx, cl in enumerate(np.unique(y)):
        plt.scatter(x=X[y == cl, 0], 
                    y=X[y == cl, 1],#画x1,x2散点图
                    alpha=0.8, 
                    c=colors[idx],
                    marker=markers[idx], 
                    label=cl, 
                    edgecolor='black')

    # highlight test samples
    if test_idx:
        # plot all samples
        X_test, y_test = X[test_idx, :], y[test_idx]

        plt.scatter(X_test[:, 0],
                    X_test[:, 1],
                    c='',
                    edgecolor='black',
                    alpha=1.0,
                    linewidth=1,
                    marker='o',
                    s=100, 
                    label='test set')

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# #  perceptron

# %% [markdown]
# Redefining the `plot_decision_region` function from chapter 2:

# %%
from sklearn.linear_model import Perceptron

ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)#支持多元分类
ppn.fit(X_train_std, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-87dd733f9625> in <module>
#       2
#       3 ppn = Perceptron(max_iter=40, eta0=0.1, random_state=1)#支持多元分类
# ----> 4 ppn.fit(X_train_std, y_train)
#
# NameError: name 'X_train_std' is not defined

# %%
y_pred = ppn.predict(X_test_std)
print('Misclassified samples: %d' % (y_test != y_pred).sum())
from sklearn.metrics import accuracy_score
print('Accuracy: %.2f' % accuracy_score(y_test, y_pred))
print('Accuracy: %.2f' % ppn.score(X_test_std, y_test))
# Out:
# Misclassified samples: 1
# Accuracy: 0.98
# Accuracy: 0.98

# %%
X_combined_std = np.vstack((X_train_std, X_test_std))
y_combined = np.hstack((y_train, y_test))

plot_decision_regions(X=X_combined_std, y=y_combined,
                      classifier=ppn, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')

plt.tight_layout()
#plt.savefig('images/03_01.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # logistic regression

# %% [markdown]
# $$J=-\frac{1}{m}\sum_{i=0}^{m}\large(\small y^{(i)}\log(\hat{y^{(i)}})+(1-y^{(i)})\log(1-\hat{y^{(i)}})\large)+\frac{\lambda}{2}||w||^{2}$$

# %%
from sklearn.linear_model import LogisticRegression#多分类

lr = LogisticRegression(C=100.0, random_state=1)#C与正则化参数lambda成反比
lr.fit(X_train_std, y_train)

print('Accuracy: %.2f' % lr.score(X_test_std, y_test))
print(lr.predict_proba(X_test_std[:3, :]))
print(lr.predict(X_test_std[:3, :]))
lr.coef_[0]

plot_decision_regions(X_combined_std, y_combined,
                      classifier=lr, test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_06.png', dpi=300)
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# D:\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:469: FutureWarning: Default multi_class will be changed to 'auto' in 0.22. Specify the multi_class option to silence this warning.
#   "this warning.", FutureWarning)
# Accuracy: 0.98
# [[3.17983737e-08 1.44886616e-01 8.55113353e-01]
#  [8.33962295e-01 1.66037705e-01 4.55557009e-12]
#  [8.48762934e-01 1.51237066e-01 4.63166788e-13]]
# [2 0 0]

# %% [markdown]
# # support vector machines
# $$min \frac{1}{2}||w||^{2}+C\sum_{i=i}^{n}\xi_{i}$$

# %% [markdown]
# ##  using slack variables
# <img src='images/03_10.png' style="width:700px;height:300px;">

# %%
from sklearn.svm import SVC

svm = SVC(kernel='linear', C=1.0, random_state=1)
svm.fit(X_train_std, y_train)

print('Accuracy: %.2f' % svm.score(X_test_std, y_test))
print(svm.predict(X_test_std[:3, :]))

plot_decision_regions(X_combined_std, 
                      y_combined,
                      classifier=svm, 
                      test_idx=range(105, 150))
plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_11.png', dpi=300)
plt.show()
# Out:
# Accuracy: 0.98
# [2 0 0]

# %% [markdown]
# ## Alternative implementations

# %%
from sklearn.linear_model import SGDClassifier

ppn = SGDClassifier(loss='perceptron', max_iter=1000)
lr = SGDClassifier(loss='log',max_iter=1000)
svm = SGDClassifier(loss='hinge', max_iter=1000)

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ## using a kernel SVM
# **高斯核**
# $$K(x^{(i)},x^{(j)})=exp\big(-\frac{||x^{(i)}-x^{(j)}||^2}{2\sigma^2}\big)$$
# <img src='images/03_13.png' style="width:600px;height:400px;">

# %%
from sklearn.svm import SVC
gammas=[0.1,0.5,1,10,50,100]
plt.figure(figsize=(20,10))
for idx in range(len(gammas)):
    svm = SVC(kernel='rbf', random_state=1, gamma=gammas[idx], C=1.0)#gamma与sigma方成反比
    svm.fit(X_train_std, y_train)

    plt.subplot(2,3,idx+1)
    plot_decision_regions(X_combined_std, y_combined,
                          classifier=svm, test_idx=range(105, 150))
    plt.xlabel('petal length [standardized]')
    plt.ylabel('petal width [standardized]')
    plt.legend(loc='upper left')
    plt.tight_layout()
    #plt.savefig('images/03_15.png', dpi=300)
    #plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # Decision tree learning

# %% [markdown]
# ##  decision tree

# %%
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(criterion='gini', 
                              max_depth=4, 
                              random_state=1)
tree.fit(X_train, y_train)

X_combined = np.vstack((X_train, X_test))
y_combined = np.hstack((y_train, y_test))
plot_decision_regions(X_combined, y_combined, 
                      classifier=tree, test_idx=range(105, 150))

plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_20.png', dpi=300)
plt.show()

# %%
import os

os.environ["PATH"] += os.pathsep + 'D:/Graphviz2.38/bin/'
from pydotplus import graph_from_dot_data
from sklearn.tree import export_graphviz

dot_data = export_graphviz(tree,
                           filled=True, 
                           rounded=True,
                           class_names=['Setosa', 
                                        'Versicolor',
                                        'Virginica'],
                           feature_names=['petal length', 
                                          'petal width'],
                           out_file=None) 
graph = graph_from_dot_data(dot_data) 
graph.write_png('tree.png')
# Out:
# True

# %% [markdown]
# <img src='tree.png' style="width:600px;height:400px;">

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# ##  random forests

# %%
from sklearn.ensemble import RandomForestClassifier

forest = RandomForestClassifier(criterion='gini',
                                n_estimators=25, #决策树数量
                                random_state=1,
                                n_jobs=2)#多核计算
forest.fit(X_train, y_train)

plot_decision_regions(X_combined, y_combined, 
                      classifier=forest, test_idx=range(105, 150))

plt.xlabel('petal length [cm]')
plt.ylabel('petal width [cm]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_22.png', dpi=300)
plt.show()

# %% [markdown]
# <br>
# <br>

# %% [markdown]
# # K-nearest neighbors
# <img src='images/03_23.png' style="width:600px;height:300px;">

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5, 
                           p=2, #p=2表示用欧氏距离
                           metric='minkowski')
knn.fit(X_train_std, y_train)

plot_decision_regions(X_combined_std, y_combined, 
                      classifier=knn, test_idx=range(105, 150))

plt.xlabel('petal length [standardized]')
plt.ylabel('petal width [standardized]')
plt.legend(loc='upper left')
plt.tight_layout()
#plt.savefig('images/03_24.png', dpi=300)
plt.show()
